# %% [markdown]
# # Gaussian Mixture Model With SIFT

# %% [markdown]
# We will try to classify our data by extracting SIFT feature from each image and buidling Gaussian Mixture Model (GMM) for them.
#
# Data
# --------------------
# We will have 3 main types of data.
#
# 1. Paintings from Wikiart
# 2. Caltech 101 data
# 3. CIFAR 10
#
# The first one is the important one, the rest two are the standard dataset that we will use to compare against others.
#
# Model Order Selction
# ----------------------------
# Selecting the number of components
#
# # BIC
# Performing the BIC experiment similar to one here
# [http://scikit-learn.org/stable/auto_examples/mixture/plot_gmm_selection.html]
#
# First load all the libraries

# %%
# Loading all the headers
import itertools
from scipy import linalg
import matplotlib as mpl
import numpy as np 
from sklearn import mixture

import skimage.io as io
import matplotlib.pyplot as plt
import uuid
from glob import glob
from scipy import misc
import os 
print os.getcwd() # Just checking current directory
print 'File exists', os.path.isfile('../code/GMM_sift/GMM_SIFT/GMM_SIFT.py')
import sys
sys.path.append('../code/GMM_sift/GMM_SIFT/')
from GMM_SIFT import GmmImageSIFT,get_sift_des, get_dense_sift_des # Loading custom class for GMM
import random
# Out:
# c:\Users\akr156\OneDrive\code\promising-patterns\paintings\ipynb
# File exists True

# %% [markdown]
# **Step 2**
# Load the files for experiment

# %%
    # ########## Main ##################
    # since we are just testing BIC we will limit loading image to few images 
    MAX_IMAGE_PER_CLASS = 10  # Load only 10 files at max
    UNIQUE_RUN_NAME = str(uuid.uuid4())  # just a random string
    
    print '-------------------------------------------------------------------'
    print 'Started BIC testing'
    print 'unique run string is ', UNIQUE_RUN_NAME
    data_dir = '..\\data\\two_class_full_size\\'
    classes = [i for i in os.listdir(data_dir) if os.path.isdir(data_dir + i)]
    # classes = ['expressionism', 'realism']
    print 'Getting data from ', os.path.abspath(data_dir)
    print 'The classes are ', classes
    c_image_collection = []  # This will hold all the image models
    for genre_i in classes:
        image_links = glob(data_dir + genre_i + '/*.jpg')
        files = [os.path.abspath(i) for i in image_links]
        image_collection = [misc.imread(i) for i in files]
        image_collection = image_collection[:MAX_IMAGE_PER_CLASS]  # limiter
        for image_i in image_collection:
            curr_GmmImageSIFT = GmmImageSIFT(image_i)
            # set the label for current image
            curr_GmmImageSIFT.label = classes.index(genre_i)
            c_image_collection.append(curr_GmmImageSIFT)
# Out:
# -------------------------------------------------------------------
# Started BIC testing
# unique run string is  39be4cc9-f3b8-4ad3-bda4-e1a7a77fe526
# Getting data from  c:\Users\akr156\OneDrive\code\promising-patterns\paintings\data\two_class_full_size
# The classes are  ['color-field-painting', 'expressionism', 'impressionism', 'realism', 'surrealism']

# %% [markdown]
# Load a sample image.

# %%
# %pylab inline    
# Pick a random image
sample_image_1 = random.choice(c_image_collection)
plt.imshow(sample_image_1.image)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# BIC Experiment
# =========================
#
# Now that we have the data, let us try the BIC experiment for different components and GMM covariance type

# %%
X = get_sift_des(sample_image_1.image)
print X.shape
# Out:
# (105, 128)

# %% [markdown]
# Let us check the BIC scores of a single image.

# %%
n_components_range = [2**i for i in range(3,7)]+[103,104]  # check for 2,4,8,...128

lowest_bic = np.infty
bic = []
# n_components_range = range(3,4) 
cv_types = ['spherical', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a mixture of Gaussians with EM
        gmm = mixture.GMM(n_components=n_components, covariance_type=cv_type)
        gmm.fit(X)
        bic.append(gmm.bic(X))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
# Plot the BIC scores

bic = np.array(bic)
color_iter = itertools.cycle(['k', 'r', 'g', 'b', 'c', 'm', 'y'])
clf = best_gmm
bars = []
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(range(len(n_components_range))) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(range(len(n_components_range)))
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)
plt.show()

# %% [markdown]
# Let us get the SIFT keypoints and descriptors for 10 images per class, append all of them and then check their BIC. First let's see how many SIFT keypoints exist.

# %%
X = get_sift_des(c_image_collection[0].image)
for sample_image_i in c_image_collection[1:]:
    curr_sift = get_sift_des(sample_image_i.image)
    X = np.vstack([X,curr_sift])
X.shape
# Out:
# (5583, 128)

# %% [markdown]
# We see that this image has above number of **SIFT keypoints**.

# %%
n_components_range = [2**i for i in range(3,8)]  # check for 2,4,8,...128

lowest_bic = np.infty
bic = []
# n_components_range = range(3,4) 
cv_types = ['spherical', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a mixture of Gaussians with EM
        gmm = mixture.GMM(n_components=n_components, covariance_type=cv_type)
        gmm.fit(X)
        bic.append(gmm.bic(X))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-fbfcdd820d23> in <module>()
#       9         # Fit a mixture of Gaussians with EM
#      10         gmm = mixture.GMM(n_components=n_components, covariance_type=cv_type)
# ---> 11         gmm.fit(X)
#      12         bic.append(gmm.bic(X))
#      13         if bic[-1] < lowest_bic:
#
# c:\Python27\lib\site-packages\sklearn\mixture\gmm.pyc in fit(self, X)
#     435                 self.means_ = cluster.KMeans(
#     436                     n_clusters=self.n_components,
# --> 437                     random_state=self.random_state).fit(X).cluster_centers_
#     438
#     439             if 'w' in self.init_params or not hasattr(self, 'weights_'):
#
# c:\Python27\lib\site-packages\sklearn\cluster\k_means_.pyc in fit(self, X, y)
#     707             precompute_distances=self.precompute_distances,
#     708             tol=self.tol, random_state=random_state, copy_x=self.copy_x,
# --> 709             n_jobs=self.n_jobs)
#     710         return self
#     711
#
# c:\Python27\lib\site-packages\sklearn\cluster\k_means_.pyc in k_means(X, n_clusters, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs)
#     265                 X, n_clusters, max_iter=max_iter, init=init, verbose=verbose,
#     266                 precompute_distances=precompute_distances, tol=tol,
# --> 267                 x_squared_norms=x_squared_norms, random_state=random_state)
#     268             # determine if these results are the best so far
#     269             if best_inertia is None or inertia < best_inertia:
#
# c:\Python27\lib\site-packages\sklearn\cluster\k_means_.pyc in _kmeans_single(X, n_clusters, max_iter, init, verbose, x_squared_norms, random_state, tol, precompute_distances)
#     377             _labels_inertia(X, x_squared_norms, centers,
#     378                             precompute_distances=precompute_distances,
# --> 379                             distances=distances)
#     380
#     381         # computation of the means is also called the M-step of EM
#
# c:\Python27\lib\site-packages\sklearn\cluster\k_means_.pyc in _labels_inertia(X, x_squared_norms, centers, precompute_distances, distances)
#     469         if precompute_distances:
#     470             return _labels_inertia_precompute_dense(X, x_squared_norms,
# --> 471                                                     centers)
#     472         inertia = _k_means._assign_labels_array(
#     473             X, x_squared_norms, centers, labels, distances=distances)
#
# c:\Python27\lib\site-packages\sklearn\cluster\k_means_.pyc in _labels_inertia_precompute_dense(X, x_squared_norms, centers)
#     415     k = centers.shape[0]
#     416     distances = euclidean_distances(centers, X, x_squared_norms,
# --> 417                                     squared=True)
#     418     labels = np.empty(n_samples, dtype=np.int32)
#     419     labels.fill(-1)
#
# c:\Python27\lib\site-packages\sklearn\metrics\pairwise.pyc in euclidean_distances(X, Y, Y_norm_squared, squared)
#     174                 "Incompatible dimensions for Y and Y_norm_squared")
#     175
# --> 176     distances = safe_sparse_dot(X, Y.T, dense_output=True)
#     177     distances *= -2
#     178     distances += XX
#
# c:\Python27\lib\site-packages\sklearn\utils\extmath.pyc in safe_sparse_dot(a, b, dense_output)
#      81         return ret
#      82     else:
# ---> 83         return np.dot(a, b)
#      84
#      85
#
# KeyboardInterrupt:

# %%
# Plot the BIC scores

bic = np.array(bic)
color_iter = itertools.cycle(['k', 'r', 'g', 'b', 'c', 'm', 'y'])
clf = best_gmm
bars = []
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(range(len(n_components_range))) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(range(len(n_components_range)))
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)
plt.show()

# %% [markdown]
# Try **Dense SIFT** to get more keypoints

# %%
import cv2
dense=cv2.FeatureDetector_create("Dense")
kp=dense.detect(sample_image_1.image)
sift=cv2.SIFT()
kp,des=sift.compute(sample_image_1.image,kp)
print des.shape
X = des
# Out:
# (456, 128)

# %%
plt.imshow(sample_image_1.image)

# %%
n_components_range = [2**i for i in range(3,8)]# check for 2,4,8,...128

lowest_bic = np.infty
bic = []
# n_components_range = range(3,4) 
# cv_types = ['spherical', 'diag', 'full']
cv_types = ['spherical','diag']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a mixture of Gaussians with EM
        gmm = mixture.GMM(n_components=n_components, covariance_type=cv_type)
        gmm.fit(X)
        bic.append(gmm.bic(X))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
# Plot the BIC scores

bic = np.array(bic)
color_iter = itertools.cycle(['k', 'r', 'g', 'b', 'c', 'm', 'y'])
clf = best_gmm
bars = []
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(range(len(n_components_range))) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(range(len(n_components_range)))
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)
plt.show()

# %% [markdown]
# RGB
# =============================
#
# Let us try the same BIC criterion testing with RGB Images

# %%
RGB=sample_image_1.image
X = np.vstack([RGB[:,:,i].ravel() for i in range(3)]).T
print X.shape
# Out:
# (15680, 3)

# %%
n_components_range = [2**i for i in range(8,11)] # 

lowest_bic = np.infty
bic = []
# n_components_range = range(3,4) 
# cv_types = ['spherical', 'diag', 'full']
cv_types = ['diag']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a mixture of Gaussians with EM
        gmm = mixture.GMM(n_components=n_components, covariance_type=cv_type)
        gmm.fit(X)
        bic.append(gmm.bic(X))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

# %%
# Plot the BIC scores

bic = np.array(bic)
color_iter = itertools.cycle(['k', 'r', 'g', 'b', 'c', 'm', 'y'])
clf = best_gmm
bars = []
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(range(len(n_components_range))) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(range(len(n_components_range)))
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)
plt.show()

# %%
clf
# Out:
# GMM(covariance_type='diag', init_params='wmc', min_covar=0.001,
#   n_components=16, n_init=1, n_iter=100, params='wmc', random_state=None,
#   thresh=0.01)

# %%
bic
# Out:
# array([-25184338.22321992, -56289951.69394585])
